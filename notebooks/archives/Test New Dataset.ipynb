# %%
import sys
sys.path.insert(0, '../scripts/')

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms as T

from itertools import count
import random
import math

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

from models import AE, BaselineNet
from utils import *

import seaborn as sns

from sklearn.metrics import accuracy_score, f1_score, roc_auc_score

from sklearn.ensemble import ExtraTreesClassifier

from sklearn.feature_selection import VarianceThreshold
from sklearn.preprocessing import OneHotEncoder

color = sns.color_palette()

# %%
df = pd.read_csv('../data/denver_prop_with_ct_clean.csv')

# %%
df = df.astype({
  'list_date': 'datetime64[ns]',
  'sale_date': 'datetime64[ns]'
})
df = df.drop(columns=['rex_property_id'])

# %%
res = gen_dataset(df, '2017-04-02', 90)

# %%
X = res['X']
y = res['y']
print('num float: ' + str(len(res['float'])))
print('num bool: ' + str(len(res['bool'])))
print('num int: ' + str(len(res['int'])))
# Out:
# num float: 45
# num bool: 9
# num int: 10

# %%
X_float = X[res['float']]

# %%
X_float
# Out:
#         bathtotalcalc  median_rental_price  \
# 5                 3.5               2672.0
# 6                 4.5               2672.0
# 10                2.0               2672.0
# 24                3.5               2672.0
# 45                3.5               2672.0
# ...               ...                  ...
# 277543            2.5               1438.0
# 277544            2.0               2628.0
# 277546            2.0               2628.0
# 277549            3.5               1821.0
# 277550            4.5               2146.0
#
#         average_annual_rent_as_percentage_of_property_value  farm_score  \
# 5                                                8.331314         100.0
# 6                                                8.331314         100.0
# 10                                               8.331314         100.0
# 24                                               8.331314         100.0
# 45                                               8.331314         100.0
# ...                                                   ...           ...
# 277543                                          24.420792          50.0
# 277544                                           7.660988         100.0
# 277546                                           7.660988         100.0
# 277549                                           4.200747           0.0
# 277550                                           4.417766         100.0
#
#         pop_density  urban_score  rural_score  built 1995 or later  \
# 5       5944.113744          2.0         68.0            80.577849
# 6       5944.113744          2.0         68.0            80.577849
# 10      5944.113744          2.0         68.0            80.577849
# 24      5944.113744          2.0         68.0            80.577849
# 45      5944.113744          2.0         68.0            80.577849
# ...             ...          ...          ...                  ...
# 277543  2063.788745         34.0         36.0            33.745875
# 277544  6679.282809          1.0         71.0             3.015682
# 277546  6679.282809          1.0         71.0             3.015682
# 277549   111.711091         64.0          6.0            40.666667
# 277550    34.668743         72.0          2.0            27.410359
#
#         built 1970-1994  built 1940-1969  ...  public_transportation  \
# 5             18.780096         0.642055  ...               0.022361
# 6             18.780096         0.642055  ...               0.022361
# 10            18.780096         0.642055  ...               0.022361
# 24            18.780096         0.642055  ...               0.022361
# 45            18.780096         0.642055  ...               0.022361
# ...                 ...              ...  ...                    ...
# 277543        64.191419         0.495050  ...               0.038314
# 277544        94.270205         1.990350  ...               0.020492
# 277546        94.270205         1.990350  ...               0.020492
# 277549        46.833333         3.444444  ...               0.004424
# 277550        57.131474        11.713147  ...               0.000000
#
#         avg_household_size  percent_mortgage  built 2014 or later  \
# 5                     3.42          0.936654             0.000000
# 6                     3.42          0.936654             0.000000
# 10                    3.42          0.936654             0.000000
# 24                    3.42          0.936654             0.000000
# 45                    3.42          0.936654             0.000000
# ...                    ...               ...                  ...
# 277543                3.82          0.497200             0.089109
# 277544                2.77          0.763071             0.000000
# 277546                2.77          0.763071             0.000000
# 277549                2.92          0.666159             0.034722
# 277550                2.76          0.742802             0.026295
#
#         built 2010-2013  built 2000-2009       <18  commute_under_30  \
# 5              0.000000         0.805778  0.326826         52.646544
# 6              0.000000         0.805778  0.326826         52.646544
# 10             0.000000         0.805778  0.326826         52.646544
# 24             0.000000         0.805778  0.326826         52.646544
# 45             0.000000         0.805778  0.326826         52.646544
# ...                 ...              ...       ...               ...
# 277543         0.134488         0.113861  0.338800         60.975610
# 277544         0.000000         0.030157  0.232877         60.092127
# 277546         0.000000         0.030157  0.232877         60.092127
# 277549         0.068889         0.303056  0.266798         47.654827
# 277550         0.000000         0.247809  0.207558         30.979644
#
#            18-59    sqft
# 5       0.616287  1678.0
# 6       0.616287  2996.0
# 10      0.616287  1400.0
# 24      0.616287  1469.0
# 45      0.616287  2635.0
# ...          ...     ...
# 277543  0.576851  2550.0
# 277544  0.623831  1424.0
# 277546  0.623831  1424.0
# 277549  0.519823  3169.0
# 277550  0.511367  2208.0
#
# [32218 rows x 45 columns]

# %%
X_bool = X[res['bool']]

# %%
X_bool
# Out:
#         CONDO  MULTI_FAMILY  OTHER  SINGLE  has_central_air  has_jacuzzi  \
# 5       False         False  False    True            False        False
# 6       False         False  False    True            False        False
# 10       True         False  False   False            False        False
# 24      False         False  False    True            False        False
# 45      False         False  False    True            False        False
# ...       ...           ...    ...     ...              ...          ...
# 277543  False         False  False    True            False        False
# 277544   True         False  False   False            False        False
# 277546   True         False  False   False            False        False
# 277549  False         False  False    True            False        False
# 277550  False         False  False    True            False        False
#
#         has_pool  has_solar  has_garage
# 5          False      False       False
# 6          False      False       False
# 10         False      False       False
# 24         False      False       False
# 45         False      False       False
# ...          ...        ...         ...
# 277543     False      False       False
# 277544     False      False       False
# 277546     False      False       False
# 277549     False      False       False
# 277550     False      False       False
#
# [32218 rows x 9 columns]

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=1c850c61-d934-4c85-b16d-3cb283df0c84' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
