# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pymc3 as pm
import chardet
import seaborn as sns

# %%
df = pd.read_csv('../../data/denver_listing_dates_with_ct.csv')

df["list_date"] = pd.to_datetime(df["list_date"])
df["sale_date"] = pd.to_datetime(df["sale_date"])

# %%
df.describe()
# Out:
#         property_id        zipcode       latitude      longitude  \
# count  4.394270e+05  439427.000000  439427.000000  439427.000000
# mean   3.002459e+08   80220.764630      39.813445    -104.979442
# std    3.720041e+08     181.469689       0.284188       0.160879
# min    1.009100e+04   80002.000000      38.996920    -105.946410
# 25%    1.383219e+08   80104.000000      39.636260    -105.082030
# 50%    1.402957e+08   80209.000000      39.744420    -104.986732
# 75%    4.363049e+08   80260.000000      39.918841    -104.875490
# max    2.146980e+09   80643.000000      40.998080    -103.890703
#
#          sale_price    index_right        ct_key
# count  3.279290e+05  439427.000000  4.394270e+05
# mean   4.681945e+05   10174.359987  8.031449e+09
# std    3.193087e+05     359.401731  2.573723e+07
# min    1.000000e+01    9604.000000  8.001008e+09
# 25%    3.120000e+05    9849.000000  8.005084e+09
# 50%    4.010000e+05   10150.000000  8.031004e+09
# 75%    5.333000e+05   10476.000000  8.059010e+09
# max    2.357500e+07   10810.000000  8.123003e+09

# %%
denver = plt.imread('../denver_map.png')
BBox = (df.longitude.min(), df.longitude.max(),      
         df.latitude.min(), df.latitude.max())
        
fig, ax = plt.subplots(figsize = (8,7))

ax.scatter(df.longitude, df.latitude, zorder=1, alpha= 0.01, c='b', s=4)
ax.set_title('Plotting Spatial Data on Denver Map')
ax.set_xlim(BBox[0],BBox[1])
ax.set_ylim(BBox[2],BBox[3])
ax.imshow(denver, zorder=0, extent = BBox, aspect= 'equal')

plt.show()

# %%
denver_df = df[(df['longitude'] >= -105.25) & 
               (df['longitude'] <= -104.55) & 
               (df['latitude'] >= 39.5) & 
               (df['latitude'] <= 40)]

# %%
denver_small = plt.imread('../denver_small.png')
BBox = (denver_df.longitude.min(), denver_df.longitude.max(),      
         denver_df.latitude.min(), denver_df.latitude.max())
        
fig, ax = plt.subplots(figsize = (8,7))

ax.scatter(denver_df.longitude, denver_df.latitude, zorder=1, alpha= 0.01, c='b', s=4)
ax.set_title('Plotting Spatial Data on Denver Map')
ax.set_xlim(BBox[0],BBox[1])
ax.set_ylim(BBox[2],BBox[3])
ax.imshow(denver_small, zorder=0, extent = BBox, aspect= 'equal')

plt.show()

# %%
prop = pd.read_csv('../../data/denver_property_info.csv')
prop = prop.rename(columns={'cc_property_id': 'property_id'})
# Out:
# /Users/namluu/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (8) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
prop.head()
# Out:
#    property_id  data_source           address    city  zipcode  \
# 0    138572150  dataharmony     4950 Dover St  Arvada    80002
# 1    322446242  dataharmony    5260 Estes Cir  Arvada    80002
# 2    138560546  dataharmony    5622 Ammons St  Arvada    80002
# 3    138555680  dataharmony  5615 Jellison St  Arvada    80002
# 4    138576011  dataharmony   5303 Arbutus St  Arvada    80002
#
#   cc_property_address_county    fips     apn property_guid  latitude  ...  \
# 0                  JEFFERSON  8059.0  004274           NaN  39.78644  ...
# 1                        NaN  8059.0     NaN           NaN  39.79225  ...
# 2                        NaN  8059.0     NaN           NaN  39.79995  ...
# 3                        NaN  8059.0     NaN           NaN  39.79878  ...
# 4                        NaN  8059.0     NaN           NaN  39.79271  ...
#
#    below_grade_bed_count  below_grade_sqft   current_use  fencing_description  \
# 0                    NaN               NaN  Multi-Family              Partial
# 1                    NaN               NaN           NaN                  NaN
# 2                    NaN               NaN           NaN                  NaN
# 3                    3.0            1120.0           NaN                 Full
# 4                    NaN            1040.0           NaN                  NaN
#
#    frontage_length  property_condition    property_quality  \
# 0              NaN    New Construction              Stucco
# 1              NaN                 NaN  Frame,Vinyl Siding
# 2              NaN                 NaN                 NaN
# 3              NaN   Updated/Remodeled               Brick
# 4              NaN                 NaN               Brick
#
#   senior_community_indicator zoning_code  zoning_description
# 0                        NaN         R-2                 NaN
# 1                        NaN           R                 NaN
# 2                        NaN         NaN                 NaN
# 3                        NaN         RES                 NaN
# 4                        NaN         RES                R-1A
#
# [5 rows x 70 columns]

# %%
df.head()
# Out:
#    property_id  zipcode  latitude  longitude  list_date  sale_date  \
# 0    666680976    80113  39.65232 -104.97613 2016-03-01        NaT
# 1    138826052    80123  39.62523 -105.08648 2016-03-01        NaT
# 2    666683709    80204  39.74122 -105.05241 2016-03-01        NaT
# 3    137981678    80241  39.91465 -104.93076 2016-03-01 2016-04-21
# 4    410875086    80202  39.74783 -104.98640 2016-03-01 2016-05-02
#
#   withdrawn_date expired_date cancelled_date current_status  sale_price  \
# 0            NaN   2016-03-01            NaN        Expired         NaN
# 1            NaN   2016-03-01            NaN        Expired         NaN
# 2            NaN   2016-03-01            NaN        Expired         NaN
# 3            NaN          NaN            NaN           Sale    320000.0
# 4            NaN          NaN            NaN           Sale    475000.0
#
#                       geometry  index_right        ct_key
# 0  POINT (-104.97613 39.65232)      10693.0  8.005006e+09
# 1  POINT (-105.08648 39.62523)       9869.0  8.059012e+09
# 2  POINT (-105.05241 39.74122)      10476.0  8.031001e+09
# 3  POINT (-104.93076 39.91465)       9719.0  8.001009e+09
# 4   POINT (-104.9864 39.74783)      10465.0  8.031002e+09

# %%
houses = pd.merge(prop, df, on='property_id')

# %%
ctdf = pd.read_csv('../../data/denver_census_tract_data.csv')

# %%
ctdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 755 entries, 0 to 754
# Columns: 112 entries, ct_key to built 2000-2009
# dtypes: float64(103), int64(9)
# memory usage: 660.8 KB

# %%
ctdf.head()
# Out:
#        ct_key  median_rental_price  \
# 0  8001007801               1316.0
# 1  8001007802               1239.0
# 2  8001007900               1482.0
# 3  8001008000               1499.0
# 4  8001008100               2203.0
#
#    average_annual_rent_as_percentage_of_property_value  farm_score  \
# 0                                           6.024884         100.0
# 1                                           9.187587         100.0
# 2                                          10.041348         100.0
# 3                                           7.532211         100.0
# 4                                          10.072085         100.0
#
#     pop_density  densely_urban_score  urban_score  suburban_score  \
# 0  15066.473217                  7.0         10.0            33.0
# 1  15270.696288                  7.0         10.0            33.0
# 2   8644.378631                 14.0          6.0            26.0
# 3   7448.779496                 17.0          3.0            23.0
# 4    820.952275                 71.0         51.0             1.0
#
#    rural_score  remote_score  ...       >1M  married  \
# 0         83.0          93.0  ...  0.056075     33.7
# 1         83.0          93.0  ...  0.000000     34.1
# 2         76.0          86.0  ...  0.015576     38.7
# 3         73.0          83.0  ...  0.000000     43.6
# 4         19.0          29.0  ...  0.000000     30.8
#
#    divorced/separated/widowed  never_married  percent_mortgage  \
# 0                        22.8           43.5          0.803738
# 1                        16.1           49.8          0.724409
# 2                        14.9           46.5          0.860395
# 3                        18.4           37.9          0.757377
# 4                        17.1           52.1          0.269231
#
#    median_mortgage_value  vacancy_rate  built 2014 or later  built 2010-2013  \
# 0               173000.0      0.057437             0.000000         0.000000
# 1               256600.0      0.063513             0.000000         0.000000
# 2               174000.0      0.058824             0.002966         0.014829
# 3               223400.0      0.027945             0.003836         0.000000
# 4                34400.0      0.136087             0.063183         0.290401
#
#    built 2000-2009
# 0         0.130339
# 1         0.015554
# 2         0.007909
# 3         0.003836
# 4         0.507898
#
# [5 rows x 112 columns]

# %%
ctdf_sm = ctdf[['ct_key', 
                'farm_score', 'densely_urban_score', 'suburban_score', 'rural_score', 'remote_score', 
                'median_rental_price', 'pop_density', 'first_time_homebuyer_score', 'luxury_communities_score', 
                'retirement_friendly_score', 'young_single_professional_score', 
                'college_student_friendly_score', 'violent_crime_rate', 
                'property_crime_rate', 'walk', 'public_transportation', 'car', 'carpool']]

ctdf_sm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 755 entries, 0 to 754
# Data columns (total 19 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ct_key                           755 non-null    int64
#  1   farm_score                       755 non-null    float64
#  2   densely_urban_score              755 non-null    float64
#  3   suburban_score                   755 non-null    float64
#  4   rural_score                      755 non-null    float64
#  5   remote_score                     755 non-null    float64
#  6   median_rental_price              755 non-null    float64
#  7   pop_density                      755 non-null    float64
#  8   first_time_homebuyer_score       755 non-null    float64
#  9   luxury_communities_score         755 non-null    float64
#  10  retirement_friendly_score        755 non-null    float64
#  11  young_single_professional_score  755 non-null    float64
#  12  college_student_friendly_score   755 non-null    float64
#  13  violent_crime_rate               755 non-null    float64
#  14  property_crime_rate              755 non-null    float64
#  15  walk                             755 non-null    float64
#  16  public_transportation            755 non-null    float64
#  17  car                              755 non-null    float64
#  18  carpool                          755 non-null    float64
# dtypes: float64(18), int64(1)
# memory usage: 112.2 KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 439427 entries, 0 to 439426
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   property_id     439427 non-null  int64
#  1   zipcode         439427 non-null  int64
#  2   latitude        439427 non-null  float64
#  3   longitude       439427 non-null  float64
#  4   list_date       439427 non-null  datetime64[ns]
#  5   sale_date       328118 non-null  datetime64[ns]
#  6   withdrawn_date  38244 non-null   object
#  7   expired_date    21638 non-null   object
#  8   cancelled_date  79 non-null      object
#  9   current_status  439427 non-null  object
#  10  sale_price      327929 non-null  float64
#  11  geometry        439427 non-null  object
#  12  index_right     439427 non-null  float64
#  13  ct_key          439427 non-null  float64
# dtypes: datetime64[ns](2), float64(5), int64(2), object(5)
# memory usage: 46.9+ MB

# %%
houses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 426847 entries, 0 to 426846
# Data columns (total 83 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   property_id                    426847 non-null  int64
#  1   data_source                    426847 non-null  object
#  2   address                        426846 non-null  object
#  3   city                           426840 non-null  object
#  4   zipcode_x                      426847 non-null  int64
#  5   cc_property_address_county     163035 non-null  object
#  6   fips                           423280 non-null  float64
#  7   apn                            89970 non-null   object
#  8   property_guid                  332 non-null     object
#  9   latitude_x                     426564 non-null  float64
#  10  longitude_x                    426564 non-null  float64
#  11  sqft                           402639 non-null  float64
#  12  state                          426604 non-null  object
#  13  lot_sqft                       350260 non-null  float64
#  14  basement_size_sqft             89397 non-null   float64
#  15  unfinished_basement_size_sqft  353 non-null     float64
#  16  year_built                     228415 non-null  float64
#  17  image_urls                     75716 non-null   object
#  18  geo_point                      426626 non-null  object
#  19  id                             252097 non-null  float64
#  20  floors_in_property             55081 non-null   float64
#  21  floors_in_building             21193 non-null   float64
#  22  garage_spaces                  139119 non-null  float64
#  23  garage_type                    82847 non-null   object
#  24  pool_spa_types                 15787 non-null   object
#  25  view_description               29762 non-null   object
#  26  porch_or_patio                 70593 non-null   object
#  27  laundry_features               91269 non-null   object
#  28  public_listing_comments        148296 non-null  object
#  29  bedrooms                       166155 non-null  float64
#  30  full_baths                     162112 non-null  float64
#  31  half_baths                     38964 non-null   float64
#  32  assessed_year                  95380 non-null   float64
#  33  assessed_total_value           48 non-null      float64
#  34  tax_amount                     147006 non-null  float64
#  35  land_lease_fee_amount          138 non-null     float64
#  36  number_of_parcels              4 non-null       float64
#  37  effective_year_built           358 non-null     float64
#  38  number_of_units                10777 non-null   float64
#  39  rooms                          66985 non-null   float64
#  40  basement_type                  119371 non-null  object
#  41  parking_features               64573 non-null   object
#  42  other_parking                  1933 non-null    object
#  43  current_occupancy_type         28736 non-null   object
#  44  heating                        90112 non-null   object
#  45  cooling                        147557 non-null  object
#  46  fireplace_count                43809 non-null   float64
#  47  water_source                   78272 non-null   object
#  48  image_update_date              295325 non-null  object
#  49  property_type                  423818 non-null  object
#  50  home_style                     211836 non-null  object
#  51  match_street_address           426773 non-null  object
#  52  has_central_air                426847 non-null  bool
#  53  has_jacuzzi                    426847 non-null  bool
#  54  has_pool                       426847 non-null  bool
#  55  has_solar                      426847 non-null  bool
#  56  has_garage                     426847 non-null  bool
#  57  garage_type_enum               82846 non-null   object
#  58  cooling_enum                   147103 non-null  object
#  59  above_grade_bed_count          138933 non-null  float64
#  60  below_grade_bed_count          81462 non-null   float64
#  61  below_grade_sqft               84419 non-null   float64
#  62  current_use                    8640 non-null    object
#  63  fencing_description            77031 non-null   object
#  64  frontage_length                52 non-null      float64
#  65  property_condition             60599 non-null   object
#  66  property_quality               179936 non-null  object
#  67  senior_community_indicator     16388 non-null   object
#  68  zoning_code                    131949 non-null  object
#  69  zoning_description             65152 non-null   object
#  70  zipcode_y                      426847 non-null  int64
#  71  latitude_y                     426847 non-null  float64
#  72  longitude_y                    426847 non-null  float64
#  73  list_date                      426847 non-null  datetime64[ns]
#  74  sale_date                      324990 non-null  datetime64[ns]
#  75  withdrawn_date                 35871 non-null   object
#  76  expired_date                   21509 non-null   object
#  77  cancelled_date                 71 non-null      object
#  78  current_status                 426847 non-null  object
#  79  sale_price                     324801 non-null  float64
#  80  geometry                       426847 non-null  object
#  81  index_right                    426847 non-null  float64
#  82  ct_key                         426847 non-null  float64
# dtypes: bool(5), datetime64[ns](2), float64(33), int64(3), object(40)
# memory usage: 259.3+ MB

# %%
percent_notnull = houses.notnull().sum() * 100 / len(df)
notnull_df = pd.DataFrame({'column_name': houses.columns, 'percent_notnull': percent_notnull})

# %%
notnull_df[notnull_df['percent_notnull'] >= 50]
# Out:
#                                column_name  percent_notnull
# property_id                    property_id        97.137181
# data_source                    data_source        97.137181
# address                            address        97.136953
# city                                  city        97.135588
# zipcode_x                        zipcode_x        97.137181
# fips                                  fips        96.325442
# latitude_x                      latitude_x        97.072779
# longitude_x                    longitude_x        97.072779
# sqft                                  sqft        91.628189
# state                                state        97.081882
# lot_sqft                          lot_sqft        79.708347
# year_built                      year_built        51.980192
# geo_point                        geo_point        97.086888
# id                                      id        57.369483
# image_update_date        image_update_date        67.206840
# property_type                property_type        96.447874
# match_street_address  match_street_address        97.120341
# has_central_air            has_central_air        97.137181
# has_jacuzzi                    has_jacuzzi        97.137181
# has_pool                          has_pool        97.137181
# has_solar                        has_solar        97.137181
# has_garage                      has_garage        97.137181
# zipcode_y                        zipcode_y        97.137181
# latitude_y                      latitude_y        97.137181
# longitude_y                    longitude_y        97.137181
# list_date                        list_date        97.137181
# sale_date                        sale_date        73.957677
# current_status              current_status        97.137181
# sale_price                      sale_price        73.914666
# geometry                          geometry        97.137181
# index_right                    index_right        97.137181
# ct_key                              ct_key        97.137181

# %%
pd.set_option('display.max_rows', notnull_df.shape[0]+1)
print(notnull_df)
# Out:
#                                                  column_name  percent_notnull
# property_id                                      property_id        97.137181
# data_source                                      data_source        97.137181
# address                                              address        97.136953
# city                                                    city        97.135588
# zipcode_x                                          zipcode_x        97.137181
# cc_property_address_county        cc_property_address_county        37.101726
# fips                                                    fips        96.325442
# apn                                                      apn        20.474391
# property_guid                                  property_guid         0.075553
# latitude_x                                        latitude_x        97.072779
# longitude_x                                      longitude_x        97.072779
# sqft                                                    sqft        91.628189
# state                                                  state        97.081882
# lot_sqft                                            lot_sqft        79.708347
# basement_size_sqft                        basement_size_sqft        20.343993
# unfinished_basement_size_sqft  unfinished_basement_size_sqft         0.080332
# year_built                                        year_built        51.980192
# image_urls                                        image_urls        17.230621
# geo_point                                          geo_point        97.086888
# id                                                        id        57.369483
# floors_in_property                        floors_in_property        12.534733
# floors_in_building                        floors_in_building         4.822872
# garage_spaces                                  garage_spaces        31.659183
# garage_type                                      garage_type        18.853416
# pool_spa_types                                pool_spa_types         3.592633
# view_description                            view_description         6.772911
# porch_or_patio                                porch_or_patio        16.064784
# laundry_features                            laundry_features        20.770003
# public_listing_comments              public_listing_comments        33.747585
# bedrooms                                            bedrooms        37.811741
# full_baths                                        full_baths        36.891679
# half_baths                                        half_baths         8.867002
# assessed_year                                  assessed_year        21.705539
# assessed_total_value                    assessed_total_value         0.010923
# tax_amount                                        tax_amount        33.454021
# land_lease_fee_amount                  land_lease_fee_amount         0.031405
# number_of_parcels                          number_of_parcels         0.000910
# effective_year_built                    effective_year_built         0.081470
# number_of_units                              number_of_units         2.452512
# rooms                                                  rooms        15.243715
# basement_type                                  basement_type        27.165149
# parking_features                            parking_features        14.694818
# other_parking                                  other_parking         0.439891
# current_occupancy_type                current_occupancy_type         6.539425
# heating                                              heating        20.506705
# cooling                                              cooling        33.579411
# fireplace_count                              fireplace_count         9.969574
# water_source                                    water_source        17.812287
# image_update_date                          image_update_date        67.206840
# property_type                                  property_type        96.447874
# home_style                                        home_style        48.207325
# match_street_address                    match_street_address        97.120341
# has_central_air                              has_central_air        97.137181
# has_jacuzzi                                      has_jacuzzi        97.137181
# has_pool                                            has_pool        97.137181
# has_solar                                          has_solar        97.137181
# has_garage                                        has_garage        97.137181
# garage_type_enum                            garage_type_enum        18.853188
# cooling_enum                                    cooling_enum        33.476095
# above_grade_bed_count                  above_grade_bed_count        31.616856
# below_grade_bed_count                  below_grade_bed_count        18.538233
# below_grade_sqft                            below_grade_sqft        19.211155
# current_use                                      current_use         1.966197
# fencing_description                      fencing_description        17.529874
# frontage_length                              frontage_length         0.011834
# property_condition                        property_condition        13.790459
# property_quality                            property_quality        40.947871
# senior_community_indicator        senior_community_indicator         3.729402
# zoning_code                                      zoning_code        30.027513
# zoning_description                        zoning_description        14.826581
# zipcode_y                                          zipcode_y        97.137181
# latitude_y                                        latitude_y        97.137181
# longitude_y                                      longitude_y        97.137181
# list_date                                          list_date        97.137181
# sale_date                                          sale_date        73.957677
# withdrawn_date                                withdrawn_date         8.163131
# expired_date                                    expired_date         4.894783
# cancelled_date                                cancelled_date         0.016157
# current_status                                current_status        97.137181
# sale_price                                        sale_price        73.914666
# geometry                                            geometry        97.137181
# index_right                                      index_right        97.137181
# ct_key                                                ct_key        97.137181

# %%
houses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 426847 entries, 0 to 426846
# Data columns (total 83 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   property_id                    426847 non-null  int64
#  1   data_source                    426847 non-null  object
#  2   address                        426846 non-null  object
#  3   city                           426840 non-null  object
#  4   zipcode_x                      426847 non-null  int64
#  5   cc_property_address_county     163035 non-null  object
#  6   fips                           423280 non-null  float64
#  7   apn                            89970 non-null   object
#  8   property_guid                  332 non-null     object
#  9   latitude_x                     426564 non-null  float64
#  10  longitude_x                    426564 non-null  float64
#  11  sqft                           402639 non-null  float64
#  12  state                          426604 non-null  object
#  13  lot_sqft                       350260 non-null  float64
#  14  basement_size_sqft             89397 non-null   float64
#  15  unfinished_basement_size_sqft  353 non-null     float64
#  16  year_built                     228415 non-null  float64
#  17  image_urls                     75716 non-null   object
#  18  geo_point                      426626 non-null  object
#  19  id                             252097 non-null  float64
#  20  floors_in_property             55081 non-null   float64
#  21  floors_in_building             21193 non-null   float64
#  22  garage_spaces                  139119 non-null  float64
#  23  garage_type                    82847 non-null   object
#  24  pool_spa_types                 15787 non-null   object
#  25  view_description               29762 non-null   object
#  26  porch_or_patio                 70593 non-null   object
#  27  laundry_features               91269 non-null   object
#  28  public_listing_comments        148296 non-null  object
#  29  bedrooms                       166155 non-null  float64
#  30  full_baths                     162112 non-null  float64
#  31  half_baths                     38964 non-null   float64
#  32  assessed_year                  95380 non-null   float64
#  33  assessed_total_value           48 non-null      float64
#  34  tax_amount                     147006 non-null  float64
#  35  land_lease_fee_amount          138 non-null     float64
#  36  number_of_parcels              4 non-null       float64
#  37  effective_year_built           358 non-null     float64
#  38  number_of_units                10777 non-null   float64
#  39  rooms                          66985 non-null   float64
#  40  basement_type                  119371 non-null  object
#  41  parking_features               64573 non-null   object
#  42  other_parking                  1933 non-null    object
#  43  current_occupancy_type         28736 non-null   object
#  44  heating                        90112 non-null   object
#  45  cooling                        147557 non-null  object
#  46  fireplace_count                43809 non-null   float64
#  47  water_source                   78272 non-null   object
#  48  image_update_date              295325 non-null  object
#  49  property_type                  423818 non-null  object
#  50  home_style                     211836 non-null  object
#  51  match_street_address           426773 non-null  object
#  52  has_central_air                426847 non-null  bool
#  53  has_jacuzzi                    426847 non-null  bool
#  54  has_pool                       426847 non-null  bool
#  55  has_solar                      426847 non-null  bool
#  56  has_garage                     426847 non-null  bool
#  57  garage_type_enum               82846 non-null   object
#  58  cooling_enum                   147103 non-null  object
#  59  above_grade_bed_count          138933 non-null  float64
#  60  below_grade_bed_count          81462 non-null   float64
#  61  below_grade_sqft               84419 non-null   float64
#  62  current_use                    8640 non-null    object
#  63  fencing_description            77031 non-null   object
#  64  frontage_length                52 non-null      float64
#  65  property_condition             60599 non-null   object
#  66  property_quality               179936 non-null  object
#  67  senior_community_indicator     16388 non-null   object
#  68  zoning_code                    131949 non-null  object
#  69  zoning_description             65152 non-null   object
#  70  zipcode_y                      426847 non-null  int64
#  71  latitude_y                     426847 non-null  float64
#  72  longitude_y                    426847 non-null  float64
#  73  list_date                      426847 non-null  datetime64[ns]
#  74  sale_date                      324990 non-null  datetime64[ns]
#  75  withdrawn_date                 35871 non-null   object
#  76  expired_date                   21509 non-null   object
#  77  cancelled_date                 71 non-null      object
#  78  current_status                 426847 non-null  object
#  79  sale_price                     324801 non-null  float64
#  80  geometry                       426847 non-null  object
#  81  index_right                    426847 non-null  float64
#  82  ct_key                         426847 non-null  float64
# dtypes: bool(5), datetime64[ns](2), float64(33), int64(3), object(40)
# memory usage: 259.3+ MB

# %%
truncated_df = houses[['property_id', 'zipcode_x', 'fips', 'latitude_x', 'longitude_x', 'sqft', 'property_type', 'has_central_air', 'has_jacuzzi', 'has_pool', 'has_solar', 'has_garage', 'list_date', 'sale_date', 'sale_price','ct_key']]

# truncated_df = houses[['property_id','list_date', 'sale_date', 'sale_price', 'bedrooms']]

# %%
truncated_df
# Out:
#         property_id  zipcode_x    fips  latitude_x  longitude_x    sqft  \
# 0         138572150      80002  8059.0    39.78644   -105.09357     NaN
# 1         138572150      80002  8059.0    39.78644   -105.09357     NaN
# 2         322446242      80002  8059.0    39.79225   -105.09622     NaN
# 3         322446242      80002  8059.0    39.79225   -105.09622     NaN
# 4         138560546      80002  8059.0    39.79995   -105.08691  1687.0
# ...             ...        ...     ...         ...          ...     ...
# 426842    503644833      80643  8123.0    40.10629   -104.52506  1288.0
# 426843    551276799      80643  8123.0    40.03606   -104.47066  1810.0
# 426844    139419740      80643  8123.0    40.10923   -104.51945  1000.0
# 426845    480458508      80643  8123.0    40.10286   -104.52007  1620.0
# 426846    480458508      80643  8123.0    40.10286   -104.52007  1620.0
#
#        property_type  has_central_air  has_jacuzzi  has_pool  has_solar  \
# 0              OTHER            False        False     False      False
# 1              OTHER            False        False     False      False
# 2              CONDO            False        False     False      False
# 3              CONDO            False        False     False      False
# 4             SINGLE            False        False     False      False
# ...              ...              ...          ...       ...        ...
# 426842        SINGLE            False        False     False      False
# 426843        SINGLE            False        False     False      False
# 426844        SINGLE            False        False     False      False
# 426845        SINGLE            False        False     False      False
# 426846        SINGLE            False        False     False      False
#
#         has_garage  list_date  sale_date  sale_price        ct_key
# 0            False 2017-09-01        NaT         NaN  8.059010e+09
# 1            False 2020-09-28        NaT         NaN  8.059010e+09
# 2            False 2017-01-15 2017-02-16    282000.0  8.059010e+09
# 3            False 2019-07-31 2019-09-24    330000.0  8.059010e+09
# 4            False 2018-05-17 2018-07-09    350000.0  8.059010e+09
# ...            ...        ...        ...         ...           ...
# 426842       False 2018-07-31 2018-09-14    294000.0  8.123003e+09
# 426843       False 2017-08-17 2017-10-11    478000.0  8.123003e+09
# 426844       False 2018-05-11 2018-07-30    140000.0  8.123003e+09
# 426845       False 2017-02-18 2017-03-24    289000.0  8.123003e+09
# 426846       False 2020-08-05        NaT         NaN  8.123003e+09
#
# [426847 rows x 16 columns]

# %%
truncated_df = truncated_df.rename(columns={"latitude_x": "latitude", 'longitude_x': 'longitude', 'zipcode_x': 'zipcode'})

# %%
clean_df = truncated_df.dropna().copy()

# %%
clean_df['sale_price_per_sqft'] = clean_df['sale_price'] / clean_df['sqft']

# %%
clean_df
# Out:
#         property_id  zipcode    fips  latitude  longitude    sqft  \
# 4         138560546    80002  8059.0  39.79995 -105.08691  1687.0
# 6         138555680    80002  8059.0  39.79878 -105.10757  2220.0
# 7         138576011    80002  8059.0  39.79271 -105.14868  1200.0
# 8         138574571    80002  8059.0  39.79170 -105.13083  2127.0
# 9         138574571    80002  8059.0  39.79170 -105.13083  2127.0
# ...             ...      ...     ...       ...        ...     ...
# 426840    577709232    80643  8001.0  39.95822 -104.54549  1996.0
# 426842    503644833    80643  8123.0  40.10629 -104.52506  1288.0
# 426843    551276799    80643  8123.0  40.03606 -104.47066  1810.0
# 426844    139419740    80643  8123.0  40.10923 -104.51945  1000.0
# 426845    480458508    80643  8123.0  40.10286 -104.52007  1620.0
#
#        property_type  has_central_air  has_jacuzzi  has_pool  has_solar  \
# 4             SINGLE            False        False     False      False
# 6             SINGLE            False        False     False      False
# 7             SINGLE            False        False     False      False
# 8             SINGLE            False        False     False      False
# 9             SINGLE            False        False     False      False
# ...              ...              ...          ...       ...        ...
# 426840        SINGLE            False        False     False      False
# 426842        SINGLE            False        False     False      False
# 426843        SINGLE            False        False     False      False
# 426844        SINGLE            False        False     False      False
# 426845        SINGLE            False        False     False      False
#
#         has_garage  list_date  sale_date  sale_price        ct_key  \
# 4            False 2018-05-17 2018-07-09    350000.0  8.059010e+09
# 6            False 2019-12-27 2020-01-31    425000.0  8.059010e+09
# 7            False 2019-03-30 2019-05-17    439900.0  8.059010e+09
# 8            False 2017-09-28 2017-10-31    462000.0  8.059010e+09
# 9            False 2019-09-11 2019-10-23    549000.0  8.059010e+09
# ...            ...        ...        ...         ...           ...
# 426840       False 2018-05-07 2018-07-20    491302.0  8.001008e+09
# 426842       False 2018-07-31 2018-09-14    294000.0  8.123003e+09
# 426843       False 2017-08-17 2017-10-11    478000.0  8.123003e+09
# 426844       False 2018-05-11 2018-07-30    140000.0  8.123003e+09
# 426845       False 2017-02-18 2017-03-24    289000.0  8.123003e+09
#
#         sale_price_per_sqft
# 4                207.468880
# 6                191.441441
# 7                366.583333
# 8                217.207334
# 9                258.110014
# ...                     ...
# 426840           246.143287
# 426842           228.260870
# 426843           264.088398
# 426844           140.000000
# 426845           178.395062
#
# [308698 rows x 17 columns]

# %%
augmented = pd.merge(clean_df, ctdf_sm, on='ct_key')

# %%
augmented.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 308698 entries, 0 to 308697
# Data columns (total 35 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   property_id                      308698 non-null  int64
#  1   zipcode                          308698 non-null  int64
#  2   fips                             308698 non-null  float64
#  3   latitude                         308698 non-null  float64
#  4   longitude                        308698 non-null  float64
#  5   sqft                             308698 non-null  float64
#  6   property_type                    308698 non-null  object
#  7   has_central_air                  308698 non-null  bool
#  8   has_jacuzzi                      308698 non-null  bool
#  9   has_pool                         308698 non-null  bool
#  10  has_solar                        308698 non-null  bool
#  11  has_garage                       308698 non-null  bool
#  12  list_date                        308698 non-null  datetime64[ns]
#  13  sale_date                        308698 non-null  datetime64[ns]
#  14  sale_price                       308698 non-null  float64
#  15  ct_key                           308698 non-null  float64
#  16  sale_price_per_sqft              308698 non-null  float64
#  17  farm_score                       308698 non-null  float64
#  18  densely_urban_score              308698 non-null  float64
#  19  suburban_score                   308698 non-null  float64
#  20  rural_score                      308698 non-null  float64
#  21  remote_score                     308698 non-null  float64
#  22  median_rental_price              308698 non-null  float64
#  23  pop_density                      308698 non-null  float64
#  24  first_time_homebuyer_score       308698 non-null  float64
#  25  luxury_communities_score         308698 non-null  float64
#  26  retirement_friendly_score        308698 non-null  float64
#  27  young_single_professional_score  308698 non-null  float64
#  28  college_student_friendly_score   308698 non-null  float64
#  29  violent_crime_rate               308698 non-null  float64
#  30  property_crime_rate              308698 non-null  float64
#  31  walk                             308698 non-null  float64
#  32  public_transportation            308698 non-null  float64
#  33  car                              308698 non-null  float64
#  34  carpool                          308698 non-null  float64
# dtypes: bool(5), datetime64[ns](2), float64(25), int64(2), object(1)
# memory usage: 74.5+ MB

# %%
augmented_features = augmented.drop(columns=['property_id', 'ct_key'])
corr = augmented_features.corr()
f, ax = plt.subplots(figsize=(12, 10))
ax = sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

# %%
to_drop = ['latitude', 'longitude', 
           'ct_key', 'suburban_score', 'rural_score', 
           'remote_score', 'sale_price', 'car', 
           'property_crime_rate', 'densely_urban_score', 
           'luxury_communities_score']
augmented_features = augmented.drop(columns=to_drop)
corr = augmented_features.corr()
f, ax = plt.subplots(figsize=(12, 10))
ax = sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

# %%
# augmented_features.to_csv('../data/denver_augmented_clean.csv', index=False)
# clean_df.to_csv('../data/denver_prop_listing_clean.csv', index=False)

# %%
augmented_features
# Out:
#         property_id  zipcode    fips    sqft property_type  has_central_air  \
# 0         138560546    80002  8059.0  1687.0        SINGLE            False
# 1         138555680    80002  8059.0  2220.0        SINGLE            False
# 2         138574571    80002  8059.0  2127.0        SINGLE            False
# 3         138574571    80002  8059.0  2127.0        SINGLE            False
# 4         138567704    80002  8059.0  1549.0        SINGLE            False
# ...             ...      ...     ...     ...           ...              ...
# 308693    517468281    80602  8001.0  1472.0         CONDO            False
# 308694    661797786    80602  8001.0  1440.0        SINGLE            False
# 308695    551997597    80603  8123.0  3051.0        SINGLE            False
# 308696    550970025    80603  8123.0  2900.0        SINGLE            False
# 308697    138171200    80640  8001.0  1754.0        SINGLE            False
#
#         has_jacuzzi  has_pool  has_solar  has_garage  ... median_rental_price  \
# 0             False     False      False       False  ...              2385.0
# 1             False     False      False       False  ...              2385.0
# 2             False     False      False       False  ...              2385.0
# 3             False     False      False       False  ...              2385.0
# 4             False     False      False       False  ...              2385.0
# ...             ...       ...        ...         ...  ...                 ...
# 308693        False     False      False       False  ...              1923.0
# 308694        False     False      False        True  ...              1220.0
# 308695        False     False      False       False  ...              1220.0
# 308696        False     False      False       False  ...              1220.0
# 308697        False     False      False       False  ...              1220.0
#
#         pop_density  first_time_homebuyer_score  retirement_friendly_score  \
# 0       3317.321845                  100.000000                  66.918255
# 1       3317.321845                  100.000000                  66.918255
# 2       3317.321845                  100.000000                  66.918255
# 3       3317.321845                  100.000000                  66.918255
# 4       3317.321845                  100.000000                  66.918255
# ...             ...                         ...                        ...
# 308693  3147.582231                    7.676923                  83.744398
# 308694  1307.892557                   57.323550                  69.171547
# 308695  1307.892557                   57.323550                  69.171547
# 308696  1307.892557                   57.323550                  69.171547
# 308697  1307.892557                   57.323550                  69.171547
#
#         young_single_professional_score  college_student_friendly_score  \
# 0                             43.566921                       67.421430
# 1                             43.566921                       67.421430
# 2                             43.566921                       67.421430
# 3                             43.566921                       67.421430
# 4                             43.566921                       67.421430
# ...                                 ...                             ...
# 308693                        44.831191                       30.092936
# 308694                        56.438041                       12.436416
# 308695                        56.438041                       12.436416
# 308696                        56.438041                       12.436416
# 308697                        56.438041                       12.436416
#
#         violent_crime_rate      walk  public_transportation   carpool
# 0                 2.764467  0.015244               0.016463  0.080793
# 1                 2.764467  0.015244               0.016463  0.080793
# 2                 2.764467  0.015244               0.016463  0.080793
# 3                 2.764467  0.015244               0.016463  0.080793
# 4                 2.764467  0.015244               0.016463  0.080793
# ...                    ...       ...                    ...       ...
# 308693            2.001334  0.007018               0.010526  0.066667
# 308694            1.000000  0.055944               0.016084  0.053147
# 308695            1.000000  0.055944               0.016084  0.053147
# 308696            1.000000  0.055944               0.016084  0.053147
# 308697            1.000000  0.055944               0.016084  0.053147
#
# [308698 rows x 24 columns]

# %%
def calculate_mean_dom(x):
  print('current: {}'.format(x['list_date']))
  before = x['list_date'] - pd.Timedelta(days=30)
  print('before: {}'.format(before))

# %%
# augmented_features.apply(calculate_mean_dom, axis=1)

# %%
# augmented_features.to_csv('../data/denver_augmented_clean.csv', index=False)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=1c850c61-d934-4c85-b16d-3cb283df0c84' target="_blank">
# <img style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
